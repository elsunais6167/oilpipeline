# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data_1000.csv')
data.head()
# Out:
#    Unnamed: 0                   timestamp  sensor_id location    pressure  \
# 0           0  2024-07-27 04:52:17.294383          0  Point 1  495.281047
# 1           1  2024-07-27 05:02:17.294383          0  Point 1  468.003144
# 2           2  2024-07-27 05:12:17.294383          0  Point 1  479.574760
# 3           3  2024-07-27 05:22:17.294383          0  Point 1  504.817864
# 4           4  2024-07-27 05:32:17.294383          0  Point 1  497.351160
#
#    temperature    flow_rate  vibration   acoustic  hydrocarbon_gas  anomalized
# 0   116.057371  2683.863049   0.098356  79.651361         0.480456           0
# 1    89.052903  2701.161790   0.104093  80.933877         0.546456           1
# 2   112.583722  2660.646839   0.098919  76.762640         0.427997           0
# 3   114.580907  2727.971523   0.100547  79.474711         0.494413           0
# 4    97.077968  2896.149854   0.099741  82.290111         0.400772           1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       300000 non-null  int64
#  1   timestamp        300000 non-null  object
#  2   sensor_id        300000 non-null  int64
#  3   location         300000 non-null  object
#  4   pressure         300000 non-null  float64
#  5   temperature      300000 non-null  float64
#  6   flow_rate        300000 non-null  float64
#  7   vibration        300000 non-null  float64
#  8   acoustic         300000 non-null  float64
#  9   hydrocarbon_gas  300000 non-null  float64
#  10  anomalized       300000 non-null  int64
# dtypes: float64(6), int64(3), object(2)
# memory usage: 25.2+ MB

# %%
data.describe()
# Out:
#           Unnamed: 0      sensor_id       pressure    temperature  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean   149999.500000     149.500000     459.863318     100.122377
# std     86602.684716      86.602204      20.036720      10.027634
# min         0.000000       0.000000     346.800941      49.977013
# 25%     74999.750000      74.750000     446.341892      93.343870
# 50%    149999.500000     149.500000     459.865097     100.113887
# 75%    224999.250000     224.250000     473.332303     106.875451
# max    299999.000000     299.000000     545.717113     145.766337
#
#            flow_rate      vibration       acoustic  hydrocarbon_gas  \
# count  300000.000000  300000.000000  300000.000000    300000.000000
# mean     2749.129503       0.100331      80.168634         0.501553
# std       125.211801       0.005909       2.542452         0.052384
# min      2180.846009       0.075895      71.062684         0.262962
# ...

# %%
# Set the style of the visualization
sns.set(style="whitegrid")

# Create histograms for each numerical variable
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

numerical_columns = ['pressure', 'temperature', 'flow_rate', 'vibration', 'acoustic', 'hydrocarbon_gas']
axes = axes.flatten()

for i, col in enumerate(numerical_columns):
    sns.histplot(data[col], kde=True, ax=axes[i])
    axes[i].set_title(f'Distribution of {col}')
    
# Remove the empty subplots
for i in range(len(numerical_columns), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()
# Out:
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Create a pairplot to visualize relationships between variables
sns.pairplot(data[numerical_columns])
plt.show()
# Out:
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Create boxplots for each numerical variable to identify outliers
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

axes = axes.flatten()

for i, col in enumerate(numerical_columns):
    sns.boxplot(data=data, y=col, ax=axes[i])
    axes[i].set_title(f'Boxplot of {col}')

# Remove the empty subplots
for i in range(len(numerical_columns), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()
# Out:
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Create histograms for each numerical variable, grouped by the anomaly column
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

axes = axes.flatten()

for i, col in enumerate(numerical_columns):
    sns.histplot(data=data, x=col, hue='anomalized', multiple='stack', ax=axes[i], kde=True)
    axes[i].set_title(f'Distribution of {col} by Anomalized')

# Remove the empty subplots
for i in range(len(numerical_columns), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()
# Out:
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Create boxplots for each numerical variable, grouped by the anomaly column
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

axes = axes.flatten()

for i, col in enumerate(numerical_columns):
    sns.boxplot(data=data, x='anomalized', y=col, ax=axes[i])
    axes[i].set_title(f'Boxplot of {col} by Anomalized')

# Remove the empty subplots
for i in range(len(numerical_columns), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()
# Out:
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\YANSILIYU\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
